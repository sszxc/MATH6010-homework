# %%
from monochromatic_k4 import *

# %%
MK4 = MonochromaticK4(20, 1)

# %%
# %%time
MK4.coloring()
# Out:
# CPU times: total: 359 ms
# Wall time: 372 ms

# %%
MK4.draw_graph(label = False, legend = False)
plt.show()
